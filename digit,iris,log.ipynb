# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from sklearn  import datasets

# %%
dg=datasets.load_digits()

# %%
dg.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'feature_names', 'target_names', 'images', 'DESCR'])

# %%
plt.gray()
plt.matshow(dg.images[9])
plt.show()

# %%
for i in range(5):
    plt.matshow(dg.images[i])
    plt.show()

# %%
from sklearn.linear_model import LogisticRegression

# %%
reg=LogisticRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
x_train,x_test,y_train,y_test=train_test_split(dg.data,dg.target,test_size=0.2)

# %%
reg.fit(x_train,y_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_predected=reg.predict(x_test)

# %%
reg.score(x_test,y_test)
# Out:
# 0.9527777777777777

# %%
reg.score(x_train,y_train)
# Out:
# 1.0

# %%
cn=confusion_matrix(y_test,y_predected)

# %%
sns.heatmap(cn,annot=True)
# Out:
# <AxesSubplot:>

# %%
len(y_test)
# Out:
# 360

# %%
360*17/100
# Out:
# 61.2

# %%
iris=datasets.load_iris()

# %%
iris.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
a_train,a_test,s_train,s_test=train_test_split(iris.data,iris.target,test_size=0.2)

# %%
reg.fit(a_test,s_test)
# Out:
# LogisticRegression()

# %%
iris.data
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
reg.predict([[5.6,2.9,3.6,1.3]])
# Out:
# array([1])

# %%
reg.score(a_test,s_test)
# Out:
# 1.0

# %%
reg.score(a_train,s_train)
# Out:
# 0.9583333333333334

# %%
s_test_pre=reg.predict(a_test)

# %%
s_test
# Out:
# array([0, 0, 2, 0, 2, 2, 2, 1, 0, 2, 2, 0, 1, 2, 1, 2, 1, 0, 1, 1, 1, 1,
#        0, 2, 1, 2, 1, 2, 1, 1])

# %%
qq=confusion_matrix(s_test,s_test_pre)

# %%
(7+12+11)/(7+12+11)
# Out:
# 1.0

# %%
sns.heatmap(qq,annot=True)
# Out:
# <AxesSubplot:>

# %%
s_train_pre=reg.predict(a_train)

# %%
s_train
# Out:
# array([2, 2, 1, 2, 2, 2, 2, 0, 0, 2, 2, 2, 1, 1, 1, 0, 2, 0, 1, 1, 2, 0,
#        1, 1, 1, 2, 0, 1, 0, 2, 2, 1, 1, 2, 1, 1, 0, 2, 0, 2, 1, 0, 1, 0,
#        2, 2, 0, 0, 0, 2, 0, 0, 0, 0, 2, 1, 0, 2, 0, 0, 0, 0, 1, 0, 2, 1,
#        0, 0, 2, 1, 1, 0, 2, 0, 2, 0, 0, 2, 2, 2, 2, 0, 1, 1, 2, 2, 1, 0,
#        0, 1, 1, 1, 1, 2, 1, 0, 2, 1, 0, 2, 0, 0, 1, 1, 2, 1, 1, 1, 0, 1,
#        0, 2, 0, 0, 2, 0, 1, 2, 1, 0])

# %%
confusion_matrix(s_train,s_train_pre)
# Out:
# array([[43,  0,  0],
#        [ 0, 34,  4],
#        [ 0,  1, 38]], dtype=int64)

# %%
(43+34+38)/(43+34+38+4+1)
# Out:
# 0.9583333333333334

# %%
dg.data
# Out:
# array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#        [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#        ...,
#        [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#        [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#        [ 0.,  0., 10., ..., 12.,  1.,  0.]])

# %%
dg.target
# Out:
# array([0, 1, 2, ..., 8, 9, 8])
